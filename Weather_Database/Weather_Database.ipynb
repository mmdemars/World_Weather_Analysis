# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Creat a set of random latitude and longitude combinations
lats = np.random.uniform(low= -90.000, high=90.000, size=2000)
lngs = np.random.uniform(low= -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the lats adn longs to a list.
coordinates = list(lat_lngs)

# %%
# Use the citypy module to determine city based on lat and long
from citipy import citipy

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_desc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avinurme
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | kimbe
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | abu jubayhah
# City not found. Skipping...
# Processing Record 15 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 16 of Set 1 | aykhal
# Processing Record 17 of Set 1 | santa fe
# Processing Record 18 of Set 1 | port hawkesbury
# Processing Record 19 of Set 1 | vila velha
# Processing Record 20 of Set 1 | maputo
# Processing Record 21 of Set 1 | torbay
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | vila franca do campo
# Processing Record 24 of Set 1 | haines junction
# Processing Record 25 of Set 1 | sur
# Processing Record 26 of Set 1 | chuy
# Processing Record 27 of Set 1 | belmonte
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | saldanha
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | nueve de julio
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | mareeba
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | kaitangata
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | bonavista
# Processing Record 38 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | chara
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | luderitz
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | bethel
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | fortuna
# Processing Record 47 of Set 1 | hofn
# Processing Record 48 of Set 1 | benalla
# Processing Record 49 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 2 | tres arroyos
# Processing Record 3 of Set 2 | jacareacanga
# Processing Record 4 of Set 2 | geraldton
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | omboue
# Processing Record 7 of Set 2 | hasaki
# Processing Record 8 of Set 2 | henties bay
# Processing Record 9 of Set 2 | pevek
# Processing Record 10 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 2 | ahipara
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | maldonado
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | dudinka
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | ancud
# Processing Record 18 of Set 2 | coxim
# Processing Record 19 of Set 2 | scarborough
# Processing Record 20 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 2 | skjervoy
# Processing Record 22 of Set 2 | livingston
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | arraial do cabo
# Processing Record 25 of Set 2 | bonfim
# Processing Record 26 of Set 2 | shangrao
# Processing Record 27 of Set 2 | port blair
# Processing Record 28 of Set 2 | pauini
# Processing Record 29 of Set 2 | bengkulu
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | evensk
# Processing Record 32 of Set 2 | coahuayana
# Processing Record 33 of Set 2 | jamestown
# Processing Record 34 of Set 2 | los llanos de aridane
# Processing Record 35 of Set 2 | mackay
# Processing Record 36 of Set 2 | dicabisagan
# Processing Record 37 of Set 2 | dubbo
# Processing Record 38 of Set 2 | sayyan
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | ust-shonosha
# Processing Record 41 of Set 2 | avera
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | castro
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | reconquista
# Processing Record 46 of Set 2 | tuktoyaktuk
# Processing Record 47 of Set 2 | dikson
# Processing Record 48 of Set 2 | kodiak
# Processing Record 49 of Set 2 | mao
# Processing Record 50 of Set 2 | vostok
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 2 of Set 3 | hermosillo
# Processing Record 3 of Set 3 | ushuaia
# Processing Record 4 of Set 3 | lorengau
# Processing Record 5 of Set 3 | georgetown
# Processing Record 6 of Set 3 | saint stephen
# Processing Record 7 of Set 3 | severo-kurilsk
# Processing Record 8 of Set 3 | baykit
# Processing Record 9 of Set 3 | green river
# Processing Record 10 of Set 3 | ponyri
# Processing Record 11 of Set 3 | kodinsk
# Processing Record 12 of Set 3 | upernavik
# Processing Record 13 of Set 3 | mount gambier
# Processing Record 14 of Set 3 | afua
# Processing Record 15 of Set 3 | constitucion
# Processing Record 16 of Set 3 | zarubino
# Processing Record 17 of Set 3 | telfs
# Processing Record 18 of Set 3 | cape town
# Processing Record 19 of Set 3 | bilma
# Processing Record 20 of Set 3 | port-gentil
# Processing Record 21 of Set 3 | kharp
# Processing Record 22 of Set 3 | harrisonville
# Processing Record 23 of Set 3 | sinnamary
# Processing Record 24 of Set 3 | campbellsville
# Processing Record 25 of Set 3 | wilkie
# Processing Record 26 of Set 3 | kanker
# Processing Record 27 of Set 3 | poitiers
# Processing Record 28 of Set 3 | thompson
# Processing Record 29 of Set 3 | acapulco
# Processing Record 30 of Set 3 | chokurdakh
# Processing Record 31 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 3 | kollam
# Processing Record 33 of Set 3 | kamenka
# Processing Record 34 of Set 3 | viedma
# Processing Record 35 of Set 3 | sedona
# Processing Record 36 of Set 3 | keningau
# Processing Record 37 of Set 3 | aksu
# Processing Record 38 of Set 3 | vaini
# Processing Record 39 of Set 3 | shitanjing
# Processing Record 40 of Set 3 | asayita
# City not found. Skipping...
# Processing Record 41 of Set 3 | thunder bay
# Processing Record 42 of Set 3 | luganville
# Processing Record 43 of Set 3 | saint-pierre
# Processing Record 44 of Set 3 | katsuura
# Processing Record 45 of Set 3 | qaanaaq
# Processing Record 46 of Set 3 | bourail
# Processing Record 47 of Set 3 | kudahuvadhoo
# Processing Record 48 of Set 3 | nanortalik
# Processing Record 49 of Set 3 | saint-joseph
# Processing Record 50 of Set 3 | fuyang
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | hargeysa
# Processing Record 3 of Set 4 | khatanga
# Processing Record 4 of Set 4 | limbe
# Processing Record 5 of Set 4 | kandi
# Processing Record 6 of Set 4 | kahului
# Processing Record 7 of Set 4 | mahebourg
# Processing Record 8 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 9 of Set 4 | lasa
# Processing Record 10 of Set 4 | cidreira
# Processing Record 11 of Set 4 | garzon
# Processing Record 12 of Set 4 | steinbach
# Processing Record 13 of Set 4 | mattru
# Processing Record 14 of Set 4 | rindal
# Processing Record 15 of Set 4 | natal
# Processing Record 16 of Set 4 | waipawa
# Processing Record 17 of Set 4 | tombouctou
# Processing Record 18 of Set 4 | cuauhtemoc
# Processing Record 19 of Set 4 | takoradi
# Processing Record 20 of Set 4 | west bay
# Processing Record 21 of Set 4 | requena
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | cotonou
# Processing Record 24 of Set 4 | saquarema
# Processing Record 25 of Set 4 | college
# Processing Record 26 of Set 4 | komsomolskiy
# Processing Record 27 of Set 4 | saint anthony
# Processing Record 28 of Set 4 | chabahar
# Processing Record 29 of Set 4 | rocha
# Processing Record 30 of Set 4 | baruun-urt
# Processing Record 31 of Set 4 | billund
# Processing Record 32 of Set 4 | mattawa
# Processing Record 33 of Set 4 | ottumwa
# Processing Record 34 of Set 4 | bandarbeyla
# Processing Record 35 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 4 | tura
# Processing Record 37 of Set 4 | lata
# Processing Record 38 of Set 4 | rapar
# Processing Record 39 of Set 4 | panzhihua
# Processing Record 40 of Set 4 | nome
# Processing Record 41 of Set 4 | kruisfontein
# Processing Record 42 of Set 4 | umm kaddadah
# Processing Record 43 of Set 4 | bambous virieux
# Processing Record 44 of Set 4 | crab hill
# City not found. Skipping...
# Processing Record 45 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 46 of Set 4 | touros
# Processing Record 47 of Set 4 | yulara
# Processing Record 48 of Set 4 | erenhot
# Processing Record 49 of Set 4 | ust-kuyga
# Processing Record 50 of Set 4 | vanimo
# Processing Record 1 of Set 5 | necochea
# Processing Record 2 of Set 5 | richards bay
# Processing Record 3 of Set 5 | conde
# Processing Record 4 of Set 5 | placido de castro
# Processing Record 5 of Set 5 | nuuk
# Processing Record 6 of Set 5 | horodnytsya
# Processing Record 7 of Set 5 | el chol
# Processing Record 8 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 5 | ponta do sol
# Processing Record 10 of Set 5 | cam ranh
# Processing Record 11 of Set 5 | tairua
# Processing Record 12 of Set 5 | greenville
# Processing Record 13 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 14 of Set 5 | toowoomba
# Processing Record 15 of Set 5 | phan thiet
# Processing Record 16 of Set 5 | campbell river
# Processing Record 17 of Set 5 | manyana
# Processing Record 18 of Set 5 | longyearbyen
# Processing Record 19 of Set 5 | alexandria
# Processing Record 20 of Set 5 | santiago
# Processing Record 21 of Set 5 | acarau
# Processing Record 22 of Set 5 | tuatapere
# Processing Record 23 of Set 5 | vero beach
# Processing Record 24 of Set 5 | naze
# Processing Record 25 of Set 5 | road town
# Processing Record 26 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 5 | quatre cocos
# Processing Record 28 of Set 5 | edd
# Processing Record 29 of Set 5 | tezu
# Processing Record 30 of Set 5 | margate
# Processing Record 31 of Set 5 | airai
# Processing Record 32 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 5 | makung
# City not found. Skipping...
# Processing Record 34 of Set 5 | marawi
# Processing Record 35 of Set 5 | olga
# Processing Record 36 of Set 5 | taoudenni
# Processing Record 37 of Set 5 | wanning
# Processing Record 38 of Set 5 | falaleu
# City not found. Skipping...
# Processing Record 39 of Set 5 | pacific grove
# Processing Record 40 of Set 5 | ismailia
# Processing Record 41 of Set 5 | umea
# Processing Record 42 of Set 5 | ippy
# Processing Record 43 of Set 5 | taltal
# Processing Record 44 of Set 5 | grand gaube
# Processing Record 45 of Set 5 | hornepayne
# Processing Record 46 of Set 5 | victoria
# Processing Record 47 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 5 | kismayo
# Processing Record 49 of Set 5 | yuxia
# Processing Record 50 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 6 | samarai
# Processing Record 2 of Set 6 | saint-louis
# Processing Record 3 of Set 6 | labuhan
# Processing Record 4 of Set 6 | ulma
# Processing Record 5 of Set 6 | aporawan
# City not found. Skipping...
# Processing Record 6 of Set 6 | cabo san lucas
# Processing Record 7 of Set 6 | buala
# Processing Record 8 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 6 | kashi
# Processing Record 10 of Set 6 | altamont
# Processing Record 11 of Set 6 | arlit
# Processing Record 12 of Set 6 | kaeo
# Processing Record 13 of Set 6 | tazovskiy
# Processing Record 14 of Set 6 | katha
# City not found. Skipping...
# Processing Record 15 of Set 6 | ostrovnoy
# Processing Record 16 of Set 6 | ust-tsilma
# Processing Record 17 of Set 6 | popondetta
# Processing Record 18 of Set 6 | tiksi
# Processing Record 19 of Set 6 | ilulissat
# Processing Record 20 of Set 6 | iralaya
# Processing Record 21 of Set 6 | yerbogachen
# Processing Record 22 of Set 6 | plettenberg bay
# Processing Record 23 of Set 6 | port augusta
# Processing Record 24 of Set 6 | zabid
# Processing Record 25 of Set 6 | padang
# Processing Record 26 of Set 6 | praia
# Processing Record 27 of Set 6 | vila
# Processing Record 28 of Set 6 | lima
# Processing Record 29 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 6 | iqaluit
# Processing Record 31 of Set 6 | wamba
# Processing Record 32 of Set 6 | abu kamal
# Processing Record 33 of Set 6 | zhezkazgan
# Processing Record 34 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 6 | huarmey
# Processing Record 36 of Set 6 | kirakira
# Processing Record 37 of Set 6 | port hedland
# Processing Record 38 of Set 6 | mar del plata
# Processing Record 39 of Set 6 | eureka
# Processing Record 40 of Set 6 | the valley
# Processing Record 41 of Set 6 | vigrestad
# Processing Record 42 of Set 6 | merauke
# Processing Record 43 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 44 of Set 6 | yazman
# Processing Record 45 of Set 6 | marrakesh
# Processing Record 46 of Set 6 | pangnirtung
# Processing Record 47 of Set 6 | salalah
# Processing Record 48 of Set 6 | rio gallegos
# Processing Record 49 of Set 6 | katangli
# Processing Record 50 of Set 6 | tortoli
# Processing Record 1 of Set 7 | innisfail
# Processing Record 2 of Set 7 | miraflores
# Processing Record 3 of Set 7 | junin
# Processing Record 4 of Set 7 | rabo de peixe
# Processing Record 5 of Set 7 | mikhaylovka
# Processing Record 6 of Set 7 | damietta
# Processing Record 7 of Set 7 | riyadh
# Processing Record 8 of Set 7 | rurrenabaque
# Processing Record 9 of Set 7 | ouadda
# Processing Record 10 of Set 7 | pochutla
# Processing Record 11 of Set 7 | timizart
# Processing Record 12 of Set 7 | kushima
# Processing Record 13 of Set 7 | marathon
# Processing Record 14 of Set 7 | meulaboh
# Processing Record 15 of Set 7 | tecoanapa
# Processing Record 16 of Set 7 | tibacuy
# Processing Record 17 of Set 7 | sao filipe
# Processing Record 18 of Set 7 | miranda
# Processing Record 19 of Set 7 | souillac
# Processing Record 20 of Set 7 | blackwater
# Processing Record 21 of Set 7 | balkanabat
# Processing Record 22 of Set 7 | nouadhibou
# Processing Record 23 of Set 7 | neryungri
# Processing Record 24 of Set 7 | esperance
# Processing Record 25 of Set 7 | launceston
# Processing Record 26 of Set 7 | acopiara
# Processing Record 27 of Set 7 | bageshwar
# Processing Record 28 of Set 7 | bunia
# Processing Record 29 of Set 7 | mason city
# Processing Record 30 of Set 7 | piacabucu
# Processing Record 31 of Set 7 | newtownards
# Processing Record 32 of Set 7 | pitimbu
# Processing Record 33 of Set 7 | havelock
# Processing Record 34 of Set 7 | grindavik
# Processing Record 35 of Set 7 | victor harbor
# Processing Record 36 of Set 7 | aklavik
# Processing Record 37 of Set 7 | boguchany
# Processing Record 38 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 39 of Set 7 | garm
# City not found. Skipping...
# Processing Record 40 of Set 7 | puerto rico
# Processing Record 41 of Set 7 | port said
# Processing Record 42 of Set 7 | mana
# Processing Record 43 of Set 7 | verkhoyansk
# Processing Record 44 of Set 7 | pedernales
# Processing Record 45 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 7 | cherskiy
# Processing Record 47 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 48 of Set 7 | asau
# Processing Record 49 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 7 | kampot
# Processing Record 1 of Set 8 | cheremshanka
# Processing Record 2 of Set 8 | claremorris
# Processing Record 3 of Set 8 | pisco
# Processing Record 4 of Set 8 | denpasar
# Processing Record 5 of Set 8 | namibe
# Processing Record 6 of Set 8 | kaitong
# Processing Record 7 of Set 8 | nam tha
# City not found. Skipping...
# Processing Record 8 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 8 | balkhash
# Processing Record 10 of Set 8 | metro
# Processing Record 11 of Set 8 | faya
# Processing Record 12 of Set 8 | siayan
# Processing Record 13 of Set 8 | saint george
# Processing Record 14 of Set 8 | vagur
# Processing Record 15 of Set 8 | neuquen
# Processing Record 16 of Set 8 | clyde river
# Processing Record 17 of Set 8 | katsiveli
# City not found. Skipping...
# Processing Record 18 of Set 8 | mandalgovi
# Processing Record 19 of Set 8 | egvekinot
# Processing Record 20 of Set 8 | mayo
# Processing Record 21 of Set 8 | tukrah
# Processing Record 22 of Set 8 | tarquinia
# Processing Record 23 of Set 8 | tulum
# Processing Record 24 of Set 8 | faanui
# Processing Record 25 of Set 8 | leh
# Processing Record 26 of Set 8 | khuzhir
# Processing Record 27 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 8 | hudson bay
# Processing Record 29 of Set 8 | klaksvik
# Processing Record 30 of Set 8 | sechura
# Processing Record 31 of Set 8 | san patricio
# Processing Record 32 of Set 8 | vao
# Processing Record 33 of Set 8 | adrar
# Processing Record 34 of Set 8 | sharan
# Processing Record 35 of Set 8 | kvareli
# Processing Record 36 of Set 8 | zlotow
# Processing Record 37 of Set 8 | payakumbuh
# Processing Record 38 of Set 8 | provideniya
# Processing Record 39 of Set 8 | ambon
# Processing Record 40 of Set 8 | quelimane
# Processing Record 41 of Set 8 | kalmunai
# Processing Record 42 of Set 8 | fairfield
# Processing Record 43 of Set 8 | paamiut
# Processing Record 44 of Set 8 | kyshtovka
# Processing Record 45 of Set 8 | roebourne
# Processing Record 46 of Set 8 | ayr
# Processing Record 47 of Set 8 | la plaine
# Processing Record 48 of Set 8 | cayenne
# Processing Record 49 of Set 8 | bijar
# Processing Record 50 of Set 8 | churapcha
# Processing Record 1 of Set 9 | benghazi
# Processing Record 2 of Set 9 | zhigansk
# Processing Record 3 of Set 9 | alice springs
# Processing Record 4 of Set 9 | yar-sale
# Processing Record 5 of Set 9 | dingle
# Processing Record 6 of Set 9 | cananeia
# Processing Record 7 of Set 9 | codrington
# Processing Record 8 of Set 9 | bubaque
# Processing Record 9 of Set 9 | verkhneuralsk
# Processing Record 10 of Set 9 | scalloway
# City not found. Skipping...
# Processing Record 11 of Set 9 | jijiga
# Processing Record 12 of Set 9 | olinda
# Processing Record 13 of Set 9 | araouane
# Processing Record 14 of Set 9 | san pedro
# Processing Record 15 of Set 9 | taywarah
# Processing Record 16 of Set 9 | kifri
# Processing Record 17 of Set 9 | lanzhou
# Processing Record 18 of Set 9 | mmathubudukwane
# Processing Record 19 of Set 9 | fatehpur
# Processing Record 20 of Set 9 | berlevag
# Processing Record 21 of Set 9 | alofi
# Processing Record 22 of Set 9 | pinyug
# Processing Record 23 of Set 9 | port hardy
# Processing Record 24 of Set 9 | half moon bay
# Processing Record 25 of Set 9 | batagay
# Processing Record 26 of Set 9 | tonj
# Processing Record 27 of Set 9 | leningradskiy
# Processing Record 28 of Set 9 | lagoa
# Processing Record 29 of Set 9 | soloneshnoye
# Processing Record 30 of Set 9 | sol-iletsk
# Processing Record 31 of Set 9 | quang ngai
# Processing Record 32 of Set 9 | broken hill
# Processing Record 33 of Set 9 | dunedin
# Processing Record 34 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 9 | port macquarie
# Processing Record 36 of Set 9 | seydi
# Processing Record 37 of Set 9 | ust-maya
# Processing Record 38 of Set 9 | ko samui
# Processing Record 39 of Set 9 | te anau
# Processing Record 40 of Set 9 | miri
# Processing Record 41 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 9 | vestmannaeyjar
# Processing Record 43 of Set 9 | ust-tarka
# Processing Record 44 of Set 9 | lompoc
# Processing Record 45 of Set 9 | kapuskasing
# Processing Record 46 of Set 9 | mouzakion
# City not found. Skipping...
# Processing Record 47 of Set 9 | mindelo
# Processing Record 48 of Set 9 | abu samrah
# Processing Record 49 of Set 9 | joao pinheiro
# Processing Record 50 of Set 9 | sessa aurunca
# Processing Record 1 of Set 10 | palencia
# Processing Record 2 of Set 10 | bambanglipuro
# Processing Record 3 of Set 10 | ahumada
# City not found. Skipping...
# Processing Record 4 of Set 10 | nemuro
# Processing Record 5 of Set 10 | paraiso
# Processing Record 6 of Set 10 | tena
# Processing Record 7 of Set 10 | sattahip
# Processing Record 8 of Set 10 | homer
# Processing Record 9 of Set 10 | vardo
# Processing Record 10 of Set 10 | awbari
# Processing Record 11 of Set 10 | elizabeth city
# Processing Record 12 of Set 10 | capaci
# Processing Record 13 of Set 10 | khorixas
# Processing Record 14 of Set 10 | kalevala
# Processing Record 15 of Set 10 | sioux lookout
# Processing Record 16 of Set 10 | chermoz
# Processing Record 17 of Set 10 | beringovskiy
# Processing Record 18 of Set 10 | port keats
# Processing Record 19 of Set 10 | juliaca
# Processing Record 20 of Set 10 | den chai
# Processing Record 21 of Set 10 | de aar
# Processing Record 22 of Set 10 | teguldet
# Processing Record 23 of Set 10 | arman
# Processing Record 24 of Set 10 | san quintin
# Processing Record 25 of Set 10 | camopi
# Processing Record 26 of Set 10 | hualmay
# Processing Record 27 of Set 10 | mpanda
# Processing Record 28 of Set 10 | melilla
# Processing Record 29 of Set 10 | ketchikan
# Processing Record 30 of Set 10 | biak
# Processing Record 31 of Set 10 | dianopolis
# City not found. Skipping...
# Processing Record 32 of Set 10 | ashqelon
# Processing Record 33 of Set 10 | anisoc
# Processing Record 34 of Set 10 | morondava
# Processing Record 35 of Set 10 | oneonta
# Processing Record 36 of Set 10 | parauna
# Processing Record 37 of Set 10 | anar darreh
# City not found. Skipping...
# Processing Record 38 of Set 10 | alindao
# Processing Record 39 of Set 10 | mehamn
# Processing Record 40 of Set 10 | bira
# Processing Record 41 of Set 10 | houma
# Processing Record 42 of Set 10 | toktogul
# Processing Record 43 of Set 10 | kampong cham
# Processing Record 44 of Set 10 | ormara
# Processing Record 45 of Set 10 | san jose
# Processing Record 46 of Set 10 | hit
# Processing Record 47 of Set 10 | gamba
# Processing Record 48 of Set 10 | soure
# Processing Record 49 of Set 10 | gilgit
# Processing Record 50 of Set 10 | luchegorsk
# Processing Record 1 of Set 11 | carutapera
# Processing Record 2 of Set 11 | channel-port aux basques
# Processing Record 3 of Set 11 | vilhena
# Processing Record 4 of Set 11 | vaitape
# Processing Record 5 of Set 11 | bara
# Processing Record 6 of Set 11 | sterling
# Processing Record 7 of Set 11 | norman wells
# Processing Record 8 of Set 11 | klamath falls
# Processing Record 9 of Set 11 | tolaga bay
# Processing Record 10 of Set 11 | lavrentiya
# Processing Record 11 of Set 11 | hami
# Processing Record 12 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 11 | maniitsoq
# Processing Record 14 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 11 | adeje
# Processing Record 16 of Set 11 | dzilam gonzalez
# Processing Record 17 of Set 11 | fleetwood
# Processing Record 18 of Set 11 | zunyi
# Processing Record 19 of Set 11 | muros
# Processing Record 20 of Set 11 | manhattan
# Processing Record 21 of Set 11 | cap malheureux
# Processing Record 22 of Set 11 | teya
# Processing Record 23 of Set 11 | okaya
# Processing Record 24 of Set 11 | saltpond
# Processing Record 25 of Set 11 | praia da vitoria
# Processing Record 26 of Set 11 | wasserburg
# Processing Record 27 of Set 11 | storforshei
# Processing Record 28 of Set 11 | linchuan
# City not found. Skipping...
# Processing Record 29 of Set 11 | fukue
# Processing Record 30 of Set 11 | rahuri
# Processing Record 31 of Set 11 | inuvik
# Processing Record 32 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 33 of Set 11 | yeppoon
# Processing Record 34 of Set 11 | igualada
# Processing Record 35 of Set 11 | opuwo
# Processing Record 36 of Set 11 | jawhar
# Processing Record 37 of Set 11 | general luna
# Processing Record 38 of Set 11 | anzio
# Processing Record 39 of Set 11 | payo
# Processing Record 40 of Set 11 | san juan
# Processing Record 41 of Set 11 | kavaratti
# Processing Record 42 of Set 11 | baie-comeau
# Processing Record 43 of Set 11 | todos santos
# Processing Record 44 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 11 | maneadero
# Processing Record 46 of Set 11 | atambua
# Processing Record 47 of Set 11 | belyy yar
# Processing Record 48 of Set 11 | alenquer
# Processing Record 49 of Set 11 | turmalina
# Processing Record 50 of Set 11 | maravilha
# Processing Record 1 of Set 12 | kostomuksha
# Processing Record 2 of Set 12 | lambarene
# Processing Record 3 of Set 12 | mahibadhoo
# Processing Record 4 of Set 12 | madoc
# Processing Record 5 of Set 12 | puerto escondido
# Processing Record 6 of Set 12 | chongwe
# Processing Record 7 of Set 12 | sibu
# Processing Record 8 of Set 12 | san rafael
# Processing Record 9 of Set 12 | lethem
# Processing Record 10 of Set 12 | chapleau
# Processing Record 11 of Set 12 | turukhansk
# Processing Record 12 of Set 12 | goba
# Processing Record 13 of Set 12 | jalu
# Processing Record 14 of Set 12 | moba
# Processing Record 15 of Set 12 | tignere
# Processing Record 16 of Set 12 | armizonskoye
# Processing Record 17 of Set 12 | vreed en hoop
# City not found. Skipping...
# Processing Record 18 of Set 12 | guerrero negro
# Processing Record 19 of Set 12 | tucumcari
# Processing Record 20 of Set 12 | mayumba
# Processing Record 21 of Set 12 | olafsvik
# Processing Record 22 of Set 12 | amapa
# Processing Record 23 of Set 12 | emet
# Processing Record 24 of Set 12 | karratha
# Processing Record 25 of Set 12 | moose factory
# Processing Record 26 of Set 12 | bahia blanca
# Processing Record 27 of Set 12 | towada
# Processing Record 28 of Set 12 | shubarkuduk
# Processing Record 29 of Set 12 | stromness
# Processing Record 30 of Set 12 | igarka
# Processing Record 31 of Set 12 | karasburg
# Processing Record 32 of Set 12 | boa vista
# Processing Record 33 of Set 12 | ewa beach
# Processing Record 34 of Set 12 | krasnoarmeyskoye
# Processing Record 35 of Set 12 | noumea
# Processing Record 36 of Set 12 | ulaangom
# Processing Record 37 of Set 12 | otofuke
# Processing Record 38 of Set 12 | dwarka
# Processing Record 39 of Set 12 | gannan
# Processing Record 40 of Set 12 | kysyl-syr
# Processing Record 41 of Set 12 | hambantota
# Processing Record 42 of Set 12 | boende
# Processing Record 43 of Set 12 | xiamen
# Processing Record 44 of Set 12 | zemio
# Processing Record 45 of Set 12 | pangai
# Processing Record 46 of Set 12 | talnakh
# Processing Record 47 of Set 12 | caravelas
# Processing Record 48 of Set 12 | mount isa
# Processing Record 49 of Set 12 | tartus
# Processing Record 50 of Set 12 | la ronge
# Processing Record 1 of Set 13 | hobyo
# Processing Record 2 of Set 13 | black river
# Processing Record 3 of Set 13 | kurilsk
# Processing Record 4 of Set 13 | bakchar
# Processing Record 5 of Set 13 | longyan
# Processing Record 6 of Set 13 | westerville
# Processing Record 7 of Set 13 | sitka
# Processing Record 8 of Set 13 | pimenta bueno
# Processing Record 9 of Set 13 | koutsouras
# Processing Record 10 of Set 13 | clarksdale
# Processing Record 11 of Set 13 | gorey
# Processing Record 12 of Set 13 | noshiro
# Processing Record 13 of Set 13 | karpathos
# Processing Record 14 of Set 13 | ponta delgada
# Processing Record 15 of Set 13 | chumikan
# Processing Record 16 of Set 13 | magistralnyy
# Processing Record 17 of Set 13 | bathsheba
# Processing Record 18 of Set 13 | ust-koksa
# Processing Record 19 of Set 13 | palana
# Processing Record 20 of Set 13 | rio grande
# Processing Record 21 of Set 13 | carlyle
# Processing Record 22 of Set 13 | lamak
# Processing Record 23 of Set 13 | sokolo
# Processing Record 24 of Set 13 | whitehorse
# Processing Record 25 of Set 13 | axim
# Processing Record 26 of Set 13 | aripuana
# Processing Record 27 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 13 | bucerias
# Processing Record 29 of Set 13 | sao joaquim
# Processing Record 30 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 13 | xinzhi
# Processing Record 32 of Set 13 | karakulino
# Processing Record 33 of Set 13 | boyolangu
# Processing Record 34 of Set 13 | okhotsk
# Processing Record 35 of Set 13 | tomobe
# Processing Record 36 of Set 13 | powell river
# Processing Record 37 of Set 13 | tilichiki
# Processing Record 38 of Set 13 | cockburn town
# Processing Record 39 of Set 13 | halifax
# Processing Record 40 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 41 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 13 | helong
# Processing Record 43 of Set 13 | hirara
# Processing Record 44 of Set 13 | kendari
# Processing Record 45 of Set 13 | dauphin
# Processing Record 46 of Set 13 | chicama
# Processing Record 47 of Set 13 | chapais
# Processing Record 48 of Set 13 | callaway
# Processing Record 49 of Set 13 | udachnyy
# Processing Record 50 of Set 13 | ahuimanu
# Processing Record 1 of Set 14 | aurillac
# Processing Record 2 of Set 14 | lazaro cardenas
# Processing Record 3 of Set 14 | kletskaya
# Processing Record 4 of Set 14 | gat
# Processing Record 5 of Set 14 | pareora
# Processing Record 6 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 14 | manoel urbano
# Processing Record 8 of Set 14 | yangjiang
# Processing Record 9 of Set 14 | george
# Processing Record 10 of Set 14 | yashkul
# Processing Record 11 of Set 14 | waterfoot
# Processing Record 12 of Set 14 | linqing
# Processing Record 13 of Set 14 | tabuk
# Processing Record 14 of Set 14 | morant bay
# Processing Record 15 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 14 | stamsund
# City not found. Skipping...
# Processing Record 17 of Set 14 | khandyga
# Processing Record 18 of Set 14 | dukat
# Processing Record 19 of Set 14 | narsaq
# Processing Record 20 of Set 14 | south san francisco
# Processing Record 21 of Set 14 | safaga
# Processing Record 22 of Set 14 | kananga
# Processing Record 23 of Set 14 | ilo
# Processing Record 24 of Set 14 | hendaye
# Processing Record 25 of Set 14 | ilawe
# Processing Record 26 of Set 14 | luang prabang
# Processing Record 27 of Set 14 | elmira
# Processing Record 28 of Set 14 | trairi
# Processing Record 29 of Set 14 | xining
# Processing Record 30 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 31 of Set 14 | price
# Processing Record 32 of Set 14 | enshi
# Processing Record 33 of Set 14 | alberton
# Processing Record 34 of Set 14 | sobolevo
# Processing Record 35 of Set 14 | camocim
# Processing Record 36 of Set 14 | guymon
# Processing Record 37 of Set 14 | vite
# Processing Record 38 of Set 14 | isangel
# Processing Record 39 of Set 14 | tsumeb
# Processing Record 40 of Set 14 | tiznit
# Processing Record 41 of Set 14 | guanare
# Processing Record 42 of Set 14 | de-kastri
# Processing Record 43 of Set 14 | severnyy
# Processing Record 44 of Set 14 | manono
# Processing Record 45 of Set 14 | qaqortoq
# Processing Record 46 of Set 14 | namatanai
# Processing Record 47 of Set 14 | serenje
# Processing Record 48 of Set 14 | khatima
# Processing Record 49 of Set 14 | peleduy
# Processing Record 50 of Set 14 | woodland
# Processing Record 1 of Set 15 | diego de almagro
# Processing Record 2 of Set 15 | batagay-alyta
# Processing Record 3 of Set 15 | atar
# Processing Record 4 of Set 15 | coihaique
# Processing Record 5 of Set 15 | brae
# Processing Record 6 of Set 15 | diamantino
# Processing Record 7 of Set 15 | coolum beach
# Processing Record 8 of Set 15 | huescar
# Processing Record 9 of Set 15 | sabha
# Processing Record 10 of Set 15 | iacu
# Processing Record 11 of Set 15 | pennadam
# Processing Record 12 of Set 15 | benicarlo
# Processing Record 13 of Set 15 | astana
# Processing Record 14 of Set 15 | pozzallo
# Processing Record 15 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 15 | pathein
# Processing Record 17 of Set 15 | huaidian
# Processing Record 18 of Set 15 | aginskoye
# Processing Record 19 of Set 15 | bousse
# Processing Record 20 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 21 of Set 15 | yandoon
# City not found. Skipping...
# Processing Record 22 of Set 15 | lemon tree passage
# Processing Record 23 of Set 15 | cururupu
# Processing Record 24 of Set 15 | imbituba
# Processing Record 25 of Set 15 | lagoa santa
# Processing Record 26 of Set 15 | sainte-suzanne
# Processing Record 27 of Set 15 | yumen
# Processing Record 28 of Set 15 | shingu
# Processing Record 29 of Set 15 | christchurch
# Processing Record 30 of Set 15 | labrea
# Processing Record 31 of Set 15 | palanga
# Processing Record 32 of Set 15 | mahon
# Processing Record 33 of Set 15 | tabou
# Processing Record 34 of Set 15 | uchiza
# Processing Record 35 of Set 15 | busok
# Processing Record 36 of Set 15 | harrison
# Processing Record 37 of Set 15 | mina
# Processing Record 38 of Set 15 | verkhnevilyuysk
# Processing Record 39 of Set 15 | abha
# Processing Record 40 of Set 15 | kirovskiy
# Processing Record 41 of Set 15 | redcliffe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 677

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0      Avinurme  58.9822   26.8642          few clouds     34.83        83
# 1  Punta Arenas -53.1500  -70.9167          light rain     42.91        75
# 2   New Norfolk -42.7826  147.0587    scattered clouds     42.71        86
# 3       Rikitea -23.1203 -134.9692       broken clouds     76.37        77
# 4        Hobart -42.8794  147.3294           clear sky     42.66        88
# 5      Tasiilaq  65.6145  -37.6368     overcast clouds     37.56        69
# 6         Kimbe  -5.5502  150.1429     overcast clouds     80.78        83
# 7          Hilo  19.7297 -155.0900          light rain     92.28        76
# 8     Hithadhoo  -0.6000   73.0833       moderate rain     81.97        82
# 9        Atuona  -9.8000 -139.0333           clear sky     78.60        75
#
#    Cloudiness  Wind Speed Country
# 0          16        5.97      EE
# 1          40       23.02      CL
# 2          36        1.01      AU
# 3          78       19.69      PF
# 4           0        4.61      AU
# 5          99        3.24      GL
# 6          99        1.99      PG
# 7          75       11.50      US
# 8         100       22.39      MV
# 9           1       15.14      PF

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Avinurme      EE  58.9822   26.8642     34.83        83          16
# 1  Punta Arenas      CL -53.1500  -70.9167     42.91        75          40
# 2   New Norfolk      AU -42.7826  147.0587     42.71        86          36
# 3       Rikitea      PF -23.1203 -134.9692     76.37        77          78
# 4        Hobart      AU -42.8794  147.3294     42.66        88           0
# 5      Tasiilaq      GL  65.6145  -37.6368     37.56        69          99
# 6         Kimbe      PG  -5.5502  150.1429     80.78        83          99
# 7          Hilo      US  19.7297 -155.0900     92.28        76          75
# 8     Hithadhoo      MV  -0.6000   73.0833     81.97        82         100
# 9        Atuona      PF  -9.8000 -139.0333     78.60        75           1
#
#    Wind Speed Current Description
# 0        5.97          few clouds
# 1       23.02          light rain
# 2        1.01    scattered clouds
# 3       19.69       broken clouds
# 4        4.61           clear sky
# 5        3.24     overcast clouds
# 6        1.99     overcast clouds
# 7       11.50          light rain
# 8       22.39       moderate rain
# 9       15.14           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
